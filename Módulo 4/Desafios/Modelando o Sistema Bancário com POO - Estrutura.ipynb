# %%
# Anotações para o desafio da aula

# Atualizar a implementação para armazenar os dados em objetos e não dicionários
# O código deve seguir o modelo de classes UML do arquivo base

# Desafio extra: Fazer o sistema funcionar!

# %%
import abc

class PessoaFisica:
    def __init__(self, nome, cpf, dat_nascimento):
        self.nome = nome
        self.cpf = cpf
        self.dat_nascimento = dat_nascimento


class Cliente(PessoaFisica):
    def __init__(self, nome, cpf, dat_nasc, endereco):
        super().__init__(nome, cpf, dat_nasc)
        self.contas = []
        self.endereco = endereco
    
    def realizar_transacao(self, conta, transacao): # Chama a transação relacionado àquela conta em específico e adiciona no historico
        pass

    def adiciona_conta(self, conta): # cria uma conta, verifica o dado e insere na lista
        pass

    def muda_dados(): # Recebe um dicionário, verifica qual dado quer mudar e faz a alteração
        pass


class Historico:
    def __init__(self):
        self.transacoes = []


class ContaCorrente:
    def __init__(self, limite_cont_saques, limite_valor_saques):
        self.limite_cont_saques = limite_cont_saques
        self.limite_valor_saques = limite_valor_saques


class Conta:
    def __init__(self, saldo, id_conta, agencia, cliente, historico, contaCorrente):
        self._saldo = saldo
        self.id_conta = id_conta
        self.agencia = agencia
        self.cliente = cliente
        self.historico = historico
        self.contaCorrente = contaCorrente

    def getSaldo():
        pass
        
    def nova_conta(cliente, id_conta):
        pass

    def sacar(valor):
        pass

    def depositar(valor):
        pass

    def extrato():
        pass


class Deposito(abc.ABC):
    @abc.abstractmethod
    def depositar(valor):
        pass


class Saque(abc.ABC):
    @abc.abstractmethod
    def sacar(valor):
        pass



class Transacao(Saque, Deposito):
    def registrar(self, transacao):
        pass
        
    def depositar(self, valor):
        pass

    def sacar(self, valor):
        pass
